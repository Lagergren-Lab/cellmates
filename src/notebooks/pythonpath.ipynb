# %%
from inference.cellmates import Cellmates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from inference.cellmates import Cellmates
#
# ModuleNotFoundError: No module named 'inference'

# %%
# use this trick to be able to use the project functions

import sys
import os

sys.path.append(os.path.dirname(os.path.abspath('../src/')))

# %%
from inference.cellmates import Cellmates

# %%
sys.path
# Out:
# ['/Users/zemp/phd/scilife/Cellmates/src/notebooks',
#  '/opt/homebrew/Cellar/python@3.10/3.10.13_2/Frameworks/Python.framework/Versions/3.10/lib/python310.zip',
#  '/opt/homebrew/Cellar/python@3.10/3.10.13_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10',
#  '/opt/homebrew/Cellar/python@3.10/3.10.13_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload',
#  '',
#  '/Users/zemp/phd/scilife/Cellmates/cellmates_env/lib/python3.10/site-packages',
#  '/Users/zemp/phd/scilife/Cellmates/src']
