# %%
pip install scikit-bio
# Out:
# Collecting scikit-bio
#   Downloading scikit-bio-0.6.0.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.9 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests>=2.20.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-bio) (2.31.0)
# Requirement already satisfied: decorator>=3.4.2 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-bio) (5.1.1)
# Collecting natsort>=4.0.3 (from scikit-bio)
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-bio) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-bio) (2.1.4)
# Requirement already satisfied: scipy>=1.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-bio) (1.11.4)
# Requirement already satisfied: h5py>=3.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-bio) (3.9.0)
# Collecting hdmedians>=0.14.1 (from scikit-bio)
#   Downloading hdmedians-0.14.2.tar.gz (7.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting biom-format (from scikit-bio)
#   Downloading biom-format-2.1.16.tar.gz (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 7.9 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Cython>=0.23 (from hdmedians>=0.14.1->scikit-bio)
#   Using cached Cython-3.0.10-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.0->scikit-bio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.0->scikit-bio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.0->scikit-bio) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20.0->scikit-bio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20.0->scikit-bio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20.0->scikit-bio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20.0->scikit-bio) (2024.2.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from biom-format->scikit-bio) (8.1.7)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->scikit-bio) (1.16.0)
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached Cython-3.0.10-py2.py3-none-any.whl (1.2 MB)
# Building wheels for collected packages: scikit-bio, hdmedians, biom-format
#   Building wheel for scikit-bio (pyproject.toml) ... done
#   Created wheel for scikit-bio: filename=scikit_bio-0.6.0-cp311-cp311-macosx_11_0_arm64.whl size=1367154 sha256=6fcead0aec7c5210264b1c1c1a917159cfa54f8e534973573db68fdf1b61f635
#   Stored in directory: /Users/marziea/Library/Caches/pip/wheels/4e/80/89/7800084092056e1cfe49693ade2da4d97b7e8d690e490dac1d
#   Building wheel for hdmedians (pyproject.toml) ... done
#   Created wheel for hdmedians: filename=hdmedians-0.14.2-cp311-cp311-macosx_11_0_arm64.whl size=131532 sha256=c6aec161ecba5c18df9ea3df7e81d19bf251bdc19acfbf5d0d339136b5170a13
#   Stored in directory: /Users/marziea/Library/Caches/pip/wheels/3f/5e/27/00e60e8474d23dd6ec28f6058a44cd23054bdd7b92445e7af6
#   Building wheel for biom-format (pyproject.toml) ... done
#   Created wheel for biom-format: filename=biom_format-2.1.16-cp311-cp311-macosx_11_0_arm64.whl size=11780234 sha256=b49adf098278de884a9c4cd2fc0ac20cc4b22e55f76b8b7c993ddf1601ae3019
#   Stored in directory: /Users/marziea/Library/Caches/pip/wheels/a5/6b/58/a879e8fbae2479a3d1a68719f3a062fe62701d6494f1b74f5e
# Successfully built scikit-bio hdmedians biom-format
# Installing collected packages: natsort, Cython, hdmedians, biom-format, scikit-bio
# Successfully installed Cython-3.0.10 biom-format-2.1.16 hdmedians-0.14.2 natsort-8.4.0 scikit-bio-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import skbio

# %%
from skbio import DistanceMatrix

# %%
from skbio.tree import nj

# %%
data = [[0,  5,  9,  9,  8], [5,  0, 10, 10,  9], [9, 10,  0,  8,  7], [9, 10,  8,  0,  3], [8,  9,  7,  3,  0]]

# %%
data
# Out:
# [[0, 5, 9, 9, 8],
#  [5, 0, 10, 10, 9],
#  [9, 10, 0, 8, 7],
#  [9, 10, 8, 0, 3],
#  [8, 9, 7, 3, 0]]

# %%
ids = list('abcde')

# %%
ids
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
dm = DistanceMatrix(data, ids)

# %%
dm

# %%
tree = nj(dm)

# %%
print(tree.ascii_art())
# Out:
#           /-d
#          |
#          |          /-c
#          |---------|
# ---------|         |          /-b
#          |          \--------|
#          |                    \-a
#          |
#           \-e

# %%
newick_str = nj(dm, result_constructor=str)

# %%
print(newick_str[:55], "...")
# Out:
# (d:2.000000, (c:4.000000, (b:3.000000, a:2.000000):3.00 ...
